# %% [markdown]
# <a href="https://colab.research.google.com/github/jinweiRao/MEng-Project/blob/master/Test_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from keras import backend as K
from keras.optimizers import SGD, Adam,RMSprop
from keras.layers import Dense,Activation,Input
import numpy as np
import pandas as pd
from keras import Sequential
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_predict
import matplotlib.pyplot as plt
from keras import optimizers, regularizers
import seaborn as sns
from keras import callbacks
from scipy.stats.stats import pearsonr
import random
import matplotlib.pyplot
from sklearn.cluster import KMeans
from sklearn import tree
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Build baseline_model

# %%
data=pd.read_csv('plant_A.csv')
data.head()
# Out:
#          lp  Temp   CaO    MgO  SiO2  Fe_total   MnO  Al2O3  TiO2   V2O5
# 0  4.736198  1649  40.0   8.63   7.8      27.5  3.38   0.91  0.45  1.473
# 1  4.436094  1654  39.6   9.99   9.2      23.0  4.14   2.60  0.68  1.945
# 2  4.499810  1664  44.8   8.80  11.0      20.2  3.45   1.58  0.76  2.070
# 3  4.140865  1680  42.4   8.10  11.5      21.1  3.76   2.47  0.88  2.161
# 4  4.081441  1671  48.8  11.73  11.8      13.3  3.26   1.48  0.78  1.976

# %%
def stdarize_data(data):
    mean = data.describe().loc['mean'].values
    std = data.describe().loc['std'].values
    stddata = (data - mean)/std
    return stddata

# %%
stddata = stdarize_data(data)
stddata.loc[:,'lp'] = data.loc[:,'lp']
stddata.head()
# Out:
#          lp      Temp       CaO       MgO      SiO2  Fe_total       MnO  \
# 0  4.736198  0.009329 -0.671236 -0.439794 -2.922204  2.626815 -2.034799
# 1  4.436094  0.270513 -0.781774  0.555023 -2.118590  1.352351 -0.943029
# 2  4.499810  0.792881  0.655222 -0.315442 -1.085373  0.559351 -1.934241
# 3  4.140865  1.628670 -0.008007 -0.827481 -0.798368  0.814244 -1.488914
# 4  4.081441  1.158539  1.760603  1.827804 -0.626165 -1.394827 -2.207183
#
#       Al2O3      TiO2      V2O5
# 0 -1.869831 -2.451391 -1.341048
# 1  1.682121 -1.622410 -0.383367
# 2 -0.461660 -1.334069 -0.129743
# 3  1.408894 -0.901557  0.054895
# 4 -0.671835 -1.261984 -0.320468

# %%
stddata.head()
# Out:
#          lp      Temp       CaO       MgO      SiO2  Fe_total       MnO  \
# 0  4.736198  0.009329 -0.671236 -0.439794 -2.922204  2.626815 -2.034799
# 1  4.436094  0.270513 -0.781774  0.555023 -2.118590  1.352351 -0.943029
# 2  4.499810  0.792881  0.655222 -0.315442 -1.085373  0.559351 -1.934241
# 3  4.140865  1.628670 -0.008007 -0.827481 -0.798368  0.814244 -1.488914
# 4  4.081441  1.158539  1.760603  1.827804 -0.626165 -1.394827 -2.207183
#
#       Al2O3      TiO2      V2O5
# 0 -1.869831 -2.451391 -1.341048
# 1  1.682121 -1.622410 -0.383367
# 2 -0.461660 -1.334069 -0.129743
# 3  1.408894 -0.901557  0.054895
# 4 -0.671835 -1.261984 -0.320468

# %%
X_tree = trial_data.loc[:,'Temp':'SiO2']
y_tree = trial_data.loc[:,'lp']
clf = tree.DecisionTreeRegressor(max_depth = 3, criterion = 'mse')
clf = clf.fit(X_tree,y_tree)
tree_result = tree.export_text(clf,feature_names = ['Temp','SiO2','MgO'])
print(tree_result)
# Out:
# |--- Temp <= 1653.50
# |   |--- MgO <= 13.70
# |   |   |--- Temp <= 1643.50
# |   |   |   |--- value: [4.47]
# |   |   |--- Temp >  1643.50
# |   |   |   |--- value: [4.36]
# |   |--- MgO >  13.70
# |   |   |--- SiO2 <= 10.35
# |   |   |   |--- value: [4.31]
# |   |   |--- SiO2 >  10.35
# |   |   |   |--- value: [4.17]
# |--- Temp >  1653.50
# |   |--- Temp <= 1663.50
# |   |   |--- MgO <= 13.46
# |   |   |   |--- value: [4.28]
# |   |   |--- MgO >  13.46
# |   |   |   |--- value: [4.15]
# |   |--- Temp >  1663.50
# |   |   |--- MgO <= 12.69
# |   |   |   |--- value: [4.18]
# |   |   |--- MgO >  12.69
# |   |   |   |--- value: [4.08]

# %%
T1 = stddata.loc[stddata['Temp']<=0.24].copy()
T2 = stddata.loc[stddata['Temp']>0.24].copy()
S1 = T1.loc[T1['SiO2'] <= 0.47].reset_index().drop(['index'],axis = 1)
S2 = T1.loc[T1['SiO2'] > 0.47].reset_index().drop(['index'],axis = 1)
S3 = T2.loc[T2['SiO2'] <= 0.33].reset_index().drop(['index'],axis = 1)
S4 = T2.loc[T2['SiO2'] > 0.33].reset_index().drop(['index'],axis = 1)
M1 = S1.loc[S1['MgO'] <= 0.72].reset_index().drop(['index'],axis = 1)
M2 = S1.loc[S1['MgO'] > 0.72].reset_index().drop(['index'],axis = 1)
M3 = S2.loc[S2['MgO'] <= 0.81].reset_index().drop(['index'],axis = 1)
M4 = S2.loc[S2['MgO'] > 0.81].reset_index().drop(['index'],axis = 1)
M5 = S3.loc[S3['MgO'] <= 0.36].reset_index().drop(['index'],axis = 1)
M6 = S3.loc[S3['MgO'] > 0.36].reset_index().drop(['index'],axis = 1)
M7 = S4.loc[S4['MgO'] <= -0.17].reset_index().drop(['index'],axis = 1)
M8 = S4.loc[S4['MgO'] > -0.17].reset_index().drop(['index'],axis = 1)

# %%
act_list = ['sigmoid','tanh','softsign','softmax','relu','elu']
opt_list = ['adam','RMSprop','Adadelta','SGD']

# %%
def baseline_model(act,opt,nums):
    model = Sequential()
    model.add(Dense(nums, input_dim = 9, activation = act))
    model.add(Dense(1, activation = 'linear'))
    model.compile(loss='mse', optimizer = opt, metrics=['mse']) 
    return model

# %%
def generate_model():
    model_list = []
    for act in act_list:
        for opt in opt_list:
            model_list.append(baseline_model(act,opt,16))
    return model_list

# %%
modelList = generate_model()
# Out:
# WARNING:tensorflow:From /Users/jinwei/anaconda3/envs/MEngProj/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def cv(df,model):
    epNum = int(len(df)/len(stddata)*150//1+1)
    kf = KFold(n_splits = 5, random_state = 10, shuffle = False)
    splits = kf.split(df)
    comparision_list = []
    for train_index,test_index in splits:
        X_train = df.loc[train_index,'Temp':'V2O5'].values
        X_test = df.loc[test_index,'Temp':'V2O5'].values
        y_train = df.loc[train_index,'lp'].values
        y_test = df.loc[test_index,'lp'].values
        model.fit(X_train, y_train, epochs = epNum, batch_size = 20, validation_data = (X_test,y_test),verbose = 0)
        prediction = model.predict(X_test).reshape(len(X_test),)
        comparision = {'prediction':prediction,'truth':y_test}
        comparision_list.append(comparision)
    return comparision_list

# %%
def modelsearch(modelList,df):
    result_list = [] 
    for model in tqdm(modelList):
        result = cv(df,model)
        result_list.append(result)
    return result_list

# %%
def allsearch():
    final_list = []
    for df in tqdm([M1,M2,M3,M4,M5,M6,M7,M8]):
        final = modelsearch(modelList,df)
        final_list.append(final)
    return final_list

# %%
M1_result = modelsearch(modelList,M1)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# WARNING:tensorflow:From /Users/jinwei/anaconda3/envs/MEngProj/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#   8%|▊         | 2/24 [02:15<25:17, 68.99s/it]

# %%
M1_result,M2_result,M3_result,M4_result,M5_result,M6_result,M7_result,M8_result = allsearch()
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.34s/it]
#
#
#
#
# 2it [01:12, 36.16s/it]
#
#
#
#
# 3it [01:49, 36.59s/it]
#
#
#
#
# 4it [02:27, 36.92s/it]
#
#
#
#
# 5it [03:03, 36.62s/it]
#
#
#
#   4%|▍         | 1/24 [03:03<1:10:15, 183.30s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:34, 34.57s/it]
#
#
#
#
# 2it [01:08, 34.41s/it]
#
#
#
#
# 3it [01:43, 34.53s/it]
#
#
#
#
# 4it [02:17, 34.53s/it]
#
#
#
#
# 5it [02:52, 34.47s/it]
#
#
#
#   8%|▊         | 2/24 [05:55<1:05:59, 179.99s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.84s/it]
#
#
#
#
# 2it [01:14, 37.19s/it]
#
#
#
#
# 3it [01:52, 37.37s/it]
#
#
#
#
# 4it [02:29, 37.33s/it]
#
#
#
#
# 5it [03:07, 37.38s/it]
#
#
#
#  12%|█▎        | 3/24 [09:02<1:03:46, 182.20s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:31, 31.52s/it]
#
#
#
#
# 2it [01:03, 31.60s/it]
#
#
#
#
# 3it [01:34, 31.54s/it]
#
#
#
#
# 4it [02:06, 31.69s/it]
#
#
#
#
# 5it [02:38, 31.59s/it]
#
#
#
#  17%|█▋        | 4/24 [11:41<58:19, 174.97s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.57s/it]
#
#
#
#
# 2it [01:12, 36.28s/it]
#
#
#
#
# 3it [01:48, 36.39s/it]
#
#
#
#
# 4it [02:24, 36.17s/it]
#
#
#
#
# 5it [03:00, 36.25s/it]
#
#
#
#  21%|██        | 5/24 [14:41<55:58, 176.76s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:34, 34.68s/it]
#
#
#
#
# 2it [01:09, 34.57s/it]
#
#
#
#
# 3it [01:43, 34.44s/it]
#
#
#
#
# 4it [02:17, 34.33s/it]
#
#
#
#
# 5it [02:51, 34.22s/it]
#
#
#
#  25%|██▌       | 6/24 [17:33<52:31, 175.09s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:37, 37.19s/it]
#
#
#
#
# 2it [01:14, 37.14s/it]
#
#
#
#
# 3it [01:51, 37.18s/it]
#
#
#
#
# 4it [02:29, 37.39s/it]
#
#
#
#
# 5it [03:06, 37.26s/it]
#
#
#
#  29%|██▉       | 7/24 [20:39<50:33, 178.45s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:31, 31.82s/it]
#
#
#
#
# 2it [01:03, 31.70s/it]
#
#
#
#
# 3it [01:35, 31.80s/it]
#
#
#
#
# 4it [02:06, 31.66s/it]
#
#
#
#
# 5it [02:39, 31.89s/it]
#
#
#
#  33%|███▎      | 8/24 [23:18<46:02, 172.63s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.11s/it]
#
#
#
#
# 2it [01:12, 36.07s/it]
#
#
#
#
# 3it [01:48, 36.10s/it]
#
#
#
#
# 4it [02:25, 36.34s/it]
#
#
#
#
# 5it [03:02, 36.50s/it]
#
#
#
#  38%|███▊      | 9/24 [26:20<43:51, 175.46s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:33, 33.99s/it]
#
#
#
#
# 2it [01:08, 34.06s/it]
#
#
#
#
# 3it [01:42, 34.19s/it]
#
#
#
#
# 4it [02:16, 34.01s/it]
#
#
#
#
# 5it [02:50, 34.05s/it]
#
#
#
#  42%|████▏     | 10/24 [29:10<40:35, 173.95s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.61s/it]
#
#
#
#
# 2it [01:13, 36.63s/it]
#
#
#
#
# 3it [01:49, 36.58s/it]
#
#
#
#
# 4it [02:26, 36.61s/it]
#
#
#
#
# 5it [03:04, 36.91s/it]
#
#
#
#  46%|████▌     | 11/24 [32:15<38:20, 176.98s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:32, 32.17s/it]
#
#
#
#
# 2it [01:04, 32.10s/it]
#
#
#
#
# 3it [01:35, 31.95s/it]
#
#
#
#
# 4it [02:07, 31.90s/it]
#
#
#
#
# 5it [02:38, 31.72s/it]
#
#
#
#  50%|█████     | 12/24 [34:53<34:18, 171.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:40, 40.40s/it]
#
#
#
#
# 2it [01:21, 40.65s/it]
#
#
#
#
# 3it [02:02, 40.60s/it]
#
#
#
#
# 4it [02:42, 40.53s/it]
#
#
#
#
# 5it [03:23, 40.64s/it]
#
#
#
#  54%|█████▍    | 13/24 [38:17<33:11, 181.08s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:38, 38.16s/it]
#
#
#
#
# 2it [01:16, 38.34s/it]
#
#
#
#
# 3it [01:55, 38.35s/it]
#
#
#
#
# 4it [02:34, 38.54s/it]
#
#
#
#
# 5it [03:13, 38.70s/it]
#
#
#
#  58%|█████▊    | 14/24 [41:30<30:47, 184.76s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:42, 42.35s/it]
#
#
#
#
# 2it [01:24, 42.19s/it]
#
#
#
#
# 3it [02:06, 42.27s/it]
#
#
#
#
# 4it [02:48, 42.26s/it]
#
#
#
#
# 5it [03:30, 42.12s/it]
#
#
#
#  62%|██████▎   | 15/24 [45:01<28:52, 192.53s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:37, 37.26s/it]
#
#
#
#
# 2it [01:14, 37.21s/it]
#
#
#
#
# 3it [01:50, 36.89s/it]
#
#
#
#
# 4it [02:26, 36.64s/it]
#
#
#
#
# 5it [03:03, 36.65s/it]
#
#
#
#  67%|██████▋   | 16/24 [48:04<25:17, 189.74s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.78s/it]
#
#
#
#
# 2it [01:14, 36.98s/it]
#
#
#
#
# 3it [01:51, 37.13s/it]
#
#
#
#
# 4it [02:28, 37.16s/it]
#
#
#
#
# 5it [03:06, 37.14s/it]
#
#
#
#  71%|███████   | 17/24 [51:10<22:00, 188.63s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:34, 34.36s/it]
#
#
#
#
# 2it [01:08, 34.34s/it]
#
#
#
#
# 3it [01:43, 34.45s/it]
#
#
#
#
# 4it [02:17, 34.42s/it]
#
#
#
#
# 5it [02:51, 34.37s/it]
#
#
#
#  75%|███████▌  | 18/24 [54:02<18:21, 183.63s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:38, 38.01s/it]
#
#
#
#
# 2it [01:15, 38.00s/it]
#
#
#
#
# 3it [01:53, 37.90s/it]
#
#
#
#
# 4it [02:31, 37.85s/it]
#
#
#
#
# 5it [03:09, 37.96s/it]
#
#
#
#  79%|███████▉  | 19/24 [57:12<15:27, 185.42s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:32, 32.48s/it]
#
#
#
#
# 2it [01:05, 32.67s/it]
#
#
#
#
# 3it [01:38, 32.64s/it]
#
#
#
#
# 4it [02:10, 32.41s/it]
#
#
#
#
# 5it [02:41, 32.26s/it]
#
#
#
#  83%|████████▎ | 20/24 [59:53<11:53, 178.37s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:36, 36.20s/it]
#
#
#
#
# 2it [01:12, 36.23s/it]
#
#
#
#
# 3it [01:48, 36.20s/it]
#
#
#
#
# 4it [02:24, 36.17s/it]
#
#
#
#
# 5it [03:00, 36.19s/it]
#
#
#
#  88%|████████▊ | 21/24 [1:02:54<08:57, 179.15s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:34, 34.75s/it]
#
#
#
#
# 2it [01:08, 34.58s/it]
#
#
#
#
# 3it [01:43, 34.49s/it]
#
#
#
#
# 4it [02:17, 34.38s/it]
#
#
#
#
# 5it [02:52, 34.63s/it]
#
#
#
#  92%|█████████▏| 22/24 [1:05:47<05:54, 177.17s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:37, 37.90s/it]
#
#
#
#
# 2it [01:14, 37.66s/it]
#
#
#
#
# 3it [01:51, 37.46s/it]
#
#
#
#
# 4it [02:29, 37.53s/it]
#
#
#
#
# 5it [03:06, 37.29s/it]
#
#
#
#  96%|█████████▌| 23/24 [1:08:53<02:59, 179.94s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:31, 31.87s/it]
#
#
#
#
# 2it [01:03, 31.91s/it]
#
#
#
#
# 3it [01:36, 32.13s/it]
#
#
#
#
# 4it [02:08, 32.02s/it]
#
#
#
#
# 5it [02:40, 32.07s/it]
#
#
#
# 100%|██████████| 24/24 [1:11:34<00:00, 174.10s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.98s/it]
#
#
#
#
# 2it [00:17,  8.91s/it]
#
#
#
#
# 3it [00:26,  8.86s/it]
#
#
#
#
# 4it [00:35,  8.80s/it]
#
#
#
#
# 5it [00:43,  8.77s/it]
#
#
#
#   4%|▍         | 1/24 [00:43<16:48, 43.83s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.15s/it]
#
#
#
#
# 2it [00:16,  8.14s/it]
#
#
#
#
# 3it [00:24,  8.14s/it]
#
#
#
#
# 4it [00:32,  8.14s/it]
#
#
#
#
# 5it [00:40,  8.14s/it]
#
#
#
#   8%|▊         | 2/24 [01:24<15:43, 42.89s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.82s/it]
#
#
#
#
# 2it [00:17,  8.82s/it]
#
#
#
#
# 3it [00:26,  8.82s/it]
#
#
#
#
# 4it [00:35,  8.81s/it]
#
#
#
#
# 5it [00:44,  8.81s/it]
#
#
#
#  12%|█▎        | 3/24 [02:08<15:08, 43.24s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.59s/it]
#
#
#
#
# 2it [00:15,  7.59s/it]
#
#
#
#
# 3it [00:22,  7.60s/it]
#
#
#
#
# 4it [00:30,  7.59s/it]
#
#
#
#
# 5it [00:38,  7.64s/it]
#
#
#
#  17%|█▋        | 4/24 [02:46<13:54, 41.71s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.76s/it]
#
#
#
#
# 2it [00:17,  8.76s/it]
#
#
#
#
# 3it [00:26,  8.79s/it]
#
#
#
#
# 4it [00:35,  8.74s/it]
#
#
#
#
# 5it [00:43,  8.73s/it]
#
#
#
#  21%|██        | 5/24 [03:30<13:23, 42.31s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.12s/it]
#
#
#
#
# 2it [00:16,  8.11s/it]
#
#
#
#
# 3it [00:24,  8.11s/it]
#
#
#
#
# 4it [00:32,  8.11s/it]
#
#
#
#
# 5it [00:40,  8.12s/it]
#
#
#
#  25%|██▌       | 6/24 [04:10<12:32, 41.79s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.78s/it]
#
#
#
#
# 2it [00:17,  8.77s/it]
#
#
#
#
# 3it [00:26,  8.78s/it]
#
#
#
#
# 4it [00:35,  8.78s/it]
#
#
#
#
# 5it [00:43,  8.78s/it]
#
#
#
#  29%|██▉       | 7/24 [04:54<12:01, 42.43s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.58s/it]
#
#
#
#
# 2it [00:15,  7.58s/it]
#
#
#
#
# 3it [00:22,  7.59s/it]
#
#
#
#
# 4it [00:30,  7.58s/it]
#
#
#
#
# 5it [00:37,  7.58s/it]
#
#
#
#  33%|███▎      | 8/24 [05:32<10:57, 41.07s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.62s/it]
#
#
#
#
# 2it [00:17,  8.61s/it]
#
#
#
#
# 3it [00:25,  8.61s/it]
#
#
#
#
# 4it [00:34,  8.62s/it]
#
#
#
#
# 5it [00:43,  8.63s/it]
#
#
#
#  38%|███▊      | 9/24 [06:15<10:25, 41.69s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.09s/it]
#
#
#
#
# 2it [00:16,  8.09s/it]
#
#
#
#
# 3it [00:24,  8.10s/it]
#
#
#
#
# 4it [00:32,  8.10s/it]
#
#
#
#
# 5it [00:40,  8.09s/it]
#
#
#
#  42%|████▏     | 10/24 [06:56<09:38, 41.33s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.78s/it]
#
#
#
#
# 2it [00:17,  8.79s/it]
#
#
#
#
# 3it [00:26,  8.79s/it]
#
#
#
#
# 4it [00:35,  8.79s/it]
#
#
#
#
# 5it [00:43,  8.79s/it]
#
#
#
#  46%|████▌     | 11/24 [07:40<09:07, 42.12s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.59s/it]
#
#
#
#
# 2it [00:15,  7.58s/it]
#
#
#
#
# 3it [00:22,  7.59s/it]
#
#
#
#
# 4it [00:30,  7.58s/it]
#
#
#
#
# 5it [00:37,  7.58s/it]
#
#
#
#  50%|█████     | 12/24 [08:18<08:10, 40.86s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.60s/it]
#
#
#
#
# 2it [00:19,  9.61s/it]
#
#
#
#
# 3it [00:28,  9.58s/it]
#
#
#
#
# 4it [00:38,  9.58s/it]
#
#
#
#
# 5it [00:47,  9.57s/it]
#
#
#
#  54%|█████▍    | 13/24 [09:06<07:52, 42.96s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.09s/it]
#
#
#
#
# 2it [00:18,  9.08s/it]
#
#
#
#
# 3it [00:27,  9.16s/it]
#
#
#
#
# 4it [00:37,  9.27s/it]
#
#
#
#
# 5it [00:46,  9.36s/it]
#
#
#
#  58%|█████▊    | 14/24 [09:52<07:20, 44.05s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:10, 10.21s/it]
#
#
#
#
# 2it [00:20, 10.17s/it]
#
#
#
#
# 3it [00:30, 10.22s/it]
#
#
#
#
# 4it [00:40, 10.26s/it]
#
#
#
#
# 5it [00:51, 10.28s/it]
#
#
#
#  62%|██████▎   | 15/24 [10:44<06:56, 46.22s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.91s/it]
#
#
#
#
# 2it [00:17,  8.90s/it]
#
#
#
#
# 3it [00:26,  8.89s/it]
#
#
#
#
# 4it [00:35,  8.79s/it]
#
#
#
#
# 5it [00:43,  8.71s/it]
#
#
#
#  67%|██████▋   | 16/24 [11:27<06:03, 45.48s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.21s/it]
#
#
#
#
# 2it [00:18,  9.23s/it]
#
#
#
#
# 3it [00:27,  9.22s/it]
#
#
#
#
# 4it [00:36,  9.18s/it]
#
#
#
#
# 5it [00:45,  9.08s/it]
#
#
#
#  71%|███████   | 17/24 [12:13<05:18, 45.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.32s/it]
#
#
#
#
# 2it [00:16,  8.31s/it]
#
#
#
#
# 3it [00:24,  8.32s/it]
#
#
#
#
# 4it [00:33,  8.32s/it]
#
#
#
#
# 5it [00:41,  8.32s/it]
#
#
#
#  75%|███████▌  | 18/24 [12:55<04:26, 44.34s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.10s/it]
#
#
#
#
# 2it [00:18,  9.09s/it]
#
#
#
#
# 3it [00:28,  9.52s/it]
#
#
#
#
# 4it [00:38,  9.49s/it]
#
#
#
#
# 5it [00:47,  9.38s/it]
#
#
#
#  79%|███████▉  | 19/24 [13:42<03:46, 45.22s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.76s/it]
#
#
#
#
# 2it [00:15,  7.75s/it]
#
#
#
#
# 3it [00:23,  7.76s/it]
#
#
#
#
# 4it [00:31,  7.78s/it]
#
#
#
#
# 5it [00:38,  7.80s/it]
#
#
#
#  83%|████████▎ | 20/24 [14:21<02:53, 43.34s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.77s/it]
#
#
#
#
# 2it [00:17,  8.80s/it]
#
#
#
#
# 3it [00:26,  8.80s/it]
#
#
#
#
# 4it [00:35,  8.79s/it]
#
#
#
#
# 5it [00:43,  8.78s/it]
#
#
#
#  88%|████████▊ | 21/24 [15:05<02:10, 43.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.19s/it]
#
#
#
#
# 2it [00:16,  8.20s/it]
#
#
#
#
# 3it [00:24,  8.20s/it]
#
#
#
#
# 4it [00:32,  8.22s/it]
#
#
#
#
# 5it [00:41,  8.22s/it]
#
#
#
#  92%|█████████▏| 22/24 [15:46<01:25, 42.80s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.91s/it]
#
#
#
#
# 2it [00:17,  8.90s/it]
#
#
#
#
# 3it [00:26,  8.91s/it]
#
#
#
#
# 4it [00:35,  8.91s/it]
#
#
#
#
# 5it [00:44,  8.90s/it]
#
#
#
#  96%|█████████▌| 23/24 [16:30<00:43, 43.31s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.67s/it]
#
#
#
#
# 2it [00:15,  7.67s/it]
#
#
#
#
# 3it [00:23,  7.67s/it]
#
#
#
#
# 4it [00:30,  7.67s/it]
#
#
#
#
# 5it [00:38,  7.67s/it]
#
#
#
# 100%|██████████| 24/24 [17:09<00:00, 41.83s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.44s/it]
#
#
#
#
# 2it [00:32, 16.43s/it]
#
#
#
#
# 3it [00:49, 16.42s/it]
#
#
#
#
# 4it [01:06, 16.52s/it]
#
#
#
#
# 5it [01:23, 16.66s/it]
#
#
#
#   4%|▍         | 1/24 [01:23<31:49, 83.00s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.05s/it]
#
#
#
#
# 2it [00:31, 15.88s/it]
#
#
#
#
# 3it [00:46, 15.73s/it]
#
#
#
#
# 4it [01:02, 15.62s/it]
#
#
#
#
# 5it [01:17, 15.56s/it]
#
#
#
#   8%|▊         | 2/24 [02:40<29:51, 81.41s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.68s/it]
#
#
#
#
# 2it [00:33, 16.70s/it]
#
#
#
#
# 3it [00:50, 16.69s/it]
#
#
#
#
# 4it [01:06, 16.72s/it]
#
#
#
#
# 5it [01:23, 16.70s/it]
#
#
#
#  12%|█▎        | 3/24 [04:04<28:43, 82.05s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.46s/it]
#
#
#
#
# 2it [00:28, 14.48s/it]
#
#
#
#
# 3it [00:43, 14.47s/it]
#
#
#
#
# 4it [00:57, 14.44s/it]
#
#
#
#
# 5it [01:12, 14.45s/it]
#
#
#
#  17%|█▋        | 4/24 [05:16<26:22, 79.12s/it]
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.47s/it]
#
#
#
#
# 2it [00:32, 16.44s/it]
#
#
#
#
# 3it [00:49, 16.45s/it]
#
#
#
#
# 4it [01:05, 16.46s/it]
#
#
#
#
# 5it [01:22, 16.43s/it]
#
#
#
#  21%|██        | 5/24 [06:38<25:20, 80.03s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.40s/it]
#
#
#
#
# 2it [00:30, 15.39s/it]
#
#
#
#
# 3it [00:46, 15.38s/it]
#
#
#
#
# 4it [01:01, 15.37s/it]
#
#
#
#
# 5it [01:16, 15.37s/it]
#
#
#
#  25%|██▌       | 6/24 [07:55<23:43, 79.08s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.61s/it]
#
#
#
#
# 2it [00:33, 16.60s/it]
#
#
#
#
# 3it [00:49, 16.61s/it]
#
#
#
#
# 4it [01:06, 16.65s/it]
#
#
#
#
# 5it [01:23, 16.83s/it]
#
#
#
#  29%|██▉       | 7/24 [09:19<22:48, 80.50s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.54s/it]
#
#
#
#
# 2it [00:28, 14.50s/it]
#
#
#
#
# 3it [00:43, 14.48s/it]
#
#
#
#
# 4it [00:57, 14.47s/it]
#
#
#
#
# 5it [01:12, 14.45s/it]
#
#
#
#  33%|███▎      | 8/24 [10:31<20:48, 78.02s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.34s/it]
#
#
#
#
# 2it [00:32, 16.34s/it]
#
#
#
#
# 3it [00:49, 16.39s/it]
#
#
#
#
# 4it [01:05, 16.39s/it]
#
#
#
#
# 5it [01:21, 16.39s/it]
#
#
#
#  38%|███▊      | 9/24 [11:53<19:48, 79.21s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.36s/it]
#
#
#
#
# 2it [00:30, 15.37s/it]
#
#
#
#
# 3it [00:46, 15.36s/it]
#
#
#
#
# 4it [01:01, 15.35s/it]
#
#
#
#
# 5it [01:16, 15.37s/it]
#
#
#
#  42%|████▏     | 10/24 [13:10<18:18, 78.50s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.69s/it]
#
#
#
#
# 2it [00:33, 16.68s/it]
#
#
#
#
# 3it [00:50, 16.72s/it]
#
#
#
#
# 4it [01:07, 16.93s/it]
#
#
#
#
# 5it [01:24, 17.07s/it]
#
#
#
#  46%|████▌     | 11/24 [14:35<17:25, 80.45s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.86s/it]
#
#
#
#
# 2it [00:29, 14.72s/it]
#
#
#
#
# 3it [00:43, 14.62s/it]
#
#
#
#
# 4it [00:58, 14.55s/it]
#
#
#
#
# 5it [01:12, 14.49s/it]
#
#
#
#  50%|█████     | 12/24 [15:47<15:36, 78.03s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:18, 18.38s/it]
#
#
#
#
# 2it [00:36, 18.33s/it]
#
#
#
#
# 3it [00:55, 18.50s/it]
#
#
#
#
# 4it [01:14, 18.59s/it]
#
#
#
#
# 5it [01:32, 18.51s/it]
#
#
#
#  54%|█████▍    | 13/24 [17:20<15:06, 82.40s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:18, 18.09s/it]
#
#
#
#
# 2it [00:36, 18.04s/it]
#
#
#
#
# 3it [00:54, 18.05s/it]
#
#
#
#
# 4it [01:12, 18.07s/it]
#
#
#
#
# 5it [01:29, 17.95s/it]
#
#
#
#  58%|█████▊    | 14/24 [18:50<14:06, 84.65s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:18, 18.58s/it]
#
#
#
#
# 2it [00:37, 18.72s/it]
#
#
#
#
# 3it [00:56, 18.89s/it]
#
#
#
#
# 4it [01:15, 18.85s/it]
#
#
#
#
# 5it [01:34, 18.80s/it]
#
#
#
#  62%|██████▎   | 15/24 [20:24<13:08, 87.57s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.74s/it]
#
#
#
#
# 2it [00:33, 16.85s/it]
#
#
#
#
# 3it [00:50, 16.93s/it]
#
#
#
#
# 4it [01:07, 16.85s/it]
#
#
#
#
# 5it [01:24, 16.91s/it]
#
#
#
#  67%|██████▋   | 16/24 [21:49<11:33, 86.70s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.79s/it]
#
#
#
#
# 2it [00:33, 16.83s/it]
#
#
#
#
# 3it [00:50, 16.81s/it]
#
#
#
#
# 4it [01:07, 16.79s/it]
#
#
#
#
# 5it [01:23, 16.79s/it]
#
#
#
#  71%|███████   | 17/24 [23:13<10:01, 85.88s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.74s/it]
#
#
#
#
# 2it [00:31, 15.74s/it]
#
#
#
#
# 3it [00:47, 15.75s/it]
#
#
#
#
# 4it [01:03, 15.75s/it]
#
#
#
#
# 5it [01:18, 15.77s/it]
#
#
#
#  75%|███████▌  | 18/24 [24:32<08:22, 83.76s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:17, 17.25s/it]
#
#
#
#
# 2it [00:34, 17.25s/it]
#
#
#
#
# 3it [00:51, 17.26s/it]
#
#
#
#
# 4it [01:09, 17.35s/it]
#
#
#
#
# 5it [01:26, 17.31s/it]
#
#
#
#  79%|███████▉  | 19/24 [25:58<07:03, 84.61s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.73s/it]
#
#
#
#
# 2it [00:29, 14.71s/it]
#
#
#
#
# 3it [00:44, 14.70s/it]
#
#
#
#
# 4it [00:58, 14.69s/it]
#
#
#
#
# 5it [01:13, 14.70s/it]
#
#
#
#  83%|████████▎ | 20/24 [27:12<05:25, 81.26s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.61s/it]
#
#
#
#
# 2it [00:33, 16.63s/it]
#
#
#
#
# 3it [00:49, 16.64s/it]
#
#
#
#
# 4it [01:06, 16.64s/it]
#
#
#
#
# 5it [01:23, 16.71s/it]
#
#
#
#  88%|████████▊ | 21/24 [28:35<04:05, 81.92s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.16s/it]
#
#
#
#
# 2it [00:32, 16.16s/it]
#
#
#
#
# 3it [00:47, 16.01s/it]
#
#
#
#
# 4it [01:03, 15.89s/it]
#
#
#
#
# 5it [01:19, 15.78s/it]
#
#
#
#  92%|█████████▏| 22/24 [29:54<02:42, 81.08s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.87s/it]
#
#
#
#
# 2it [00:33, 16.87s/it]
#
#
#
#
# 3it [00:50, 16.90s/it]
#
#
#
#
# 4it [01:07, 16.89s/it]
#
#
#
#
# 5it [01:24, 16.90s/it]
#
#
#
#  96%|█████████▌| 23/24 [31:19<01:22, 82.10s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.07s/it]
#
#
#
#
# 2it [00:30, 15.06s/it]
#
#
#
#
# 3it [00:45, 15.06s/it]
#
#
#
#
# 4it [01:00, 15.06s/it]
#
#
#
#
# 5it [01:15, 14.98s/it]
#
#
#
# 100%|██████████| 24/24 [32:34<00:00, 79.98s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.95s/it]
#
#
#
#
# 2it [00:05,  2.94s/it]
#
#
#
#
# 3it [00:09,  3.03s/it]
#
#
#
#
# 4it [00:12,  3.15s/it]
#
#
#
#
# 5it [00:16,  3.42s/it]
#
#
#
#   4%|▍         | 1/24 [00:16<06:21, 16.59s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.96s/it]
#
#
#
#
# 2it [00:07,  3.83s/it]
#
#
#
#
# 3it [00:11,  3.79s/it]
#
#
#
#
# 4it [00:14,  3.68s/it]
#
#
#
#
# 5it [00:17,  3.40s/it]
#
#
#
#   8%|▊         | 2/24 [00:33<06:10, 16.82s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.96s/it]
#
#
#
#
# 2it [00:05,  2.96s/it]
#
#
#
#
# 3it [00:08,  2.97s/it]
#
#
#
#
# 4it [00:11,  2.97s/it]
#
#
#
#
# 5it [00:14,  2.99s/it]
#
#
#
#  12%|█▎        | 3/24 [00:48<05:41, 16.25s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.62s/it]
#
#
#
#
# 2it [00:05,  2.60s/it]
#
#
#
#
# 3it [00:07,  2.59s/it]
#
#
#
#
# 4it [00:10,  2.58s/it]
#
#
#
#
# 5it [00:12,  2.58s/it]
#
#
#
#  17%|█▋        | 4/24 [01:01<05:04, 15.24s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.92s/it]
#
#
#
#
# 2it [00:05,  2.93s/it]
#
#
#
#
# 3it [00:08,  2.92s/it]
#
#
#
#
# 4it [00:11,  2.92s/it]
#
#
#
#
# 5it [00:14,  2.92s/it]
#
#
#
#  21%|██        | 5/24 [01:16<04:45, 15.05s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.76s/it]
#
#
#
#
# 2it [00:05,  2.75s/it]
#
#
#
#
# 3it [00:08,  2.75s/it]
#
#
#
#
# 4it [00:10,  2.74s/it]
#
#
#
#
# 5it [00:13,  2.74s/it]
#
#
#
#  25%|██▌       | 6/24 [01:30<04:23, 14.65s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.98s/it]
#
#
#
#
# 2it [00:05,  2.97s/it]
#
#
#
#
# 3it [00:08,  2.97s/it]
#
#
#
#
# 4it [00:11,  2.96s/it]
#
#
#
#
# 5it [00:14,  2.96s/it]
#
#
#
#  29%|██▉       | 7/24 [01:44<04:09, 14.70s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.57s/it]
#
#
#
#
# 2it [00:05,  2.57s/it]
#
#
#
#
# 3it [00:07,  2.56s/it]
#
#
#
#
# 4it [00:10,  2.56s/it]
#
#
#
#
# 5it [00:12,  2.56s/it]
#
#
#
#  33%|███▎      | 8/24 [01:57<03:46, 14.13s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.95s/it]
#
#
#
#
# 2it [00:05,  2.96s/it]
#
#
#
#
# 3it [00:08,  2.94s/it]
#
#
#
#
# 4it [00:11,  2.93s/it]
#
#
#
#
# 5it [00:14,  2.93s/it]
#
#
#
#  38%|███▊      | 9/24 [02:12<03:34, 14.29s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.73s/it]
#
#
#
#
# 2it [00:05,  2.74s/it]
#
#
#
#
# 3it [00:08,  2.73s/it]
#
#
#
#
# 4it [00:10,  2.74s/it]
#
#
#
#
# 5it [00:13,  2.73s/it]
#
#
#
#  42%|████▏     | 10/24 [02:26<03:17, 14.11s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.97s/it]
#
#
#
#
# 2it [00:05,  2.97s/it]
#
#
#
#
# 3it [00:08,  2.97s/it]
#
#
#
#
# 4it [00:11,  2.98s/it]
#
#
#
#
# 5it [00:14,  2.98s/it]
#
#
#
#  46%|████▌     | 11/24 [02:40<03:06, 14.34s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.56s/it]
#
#
#
#
# 2it [00:05,  2.56s/it]
#
#
#
#
# 3it [00:07,  2.58s/it]
#
#
#
#
# 4it [00:10,  2.59s/it]
#
#
#
#
# 5it [00:12,  2.58s/it]
#
#
#
#  50%|█████     | 12/24 [02:53<02:47, 13.92s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.21s/it]
#
#
#
#
# 2it [00:06,  3.21s/it]
#
#
#
#
# 3it [00:09,  3.20s/it]
#
#
#
#
# 4it [00:12,  3.20s/it]
#
#
#
#
# 5it [00:16,  3.20s/it]
#
#
#
#  54%|█████▍    | 13/24 [03:09<02:40, 14.55s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.03s/it]
#
#
#
#
# 2it [00:06,  3.03s/it]
#
#
#
#
# 3it [00:09,  3.03s/it]
#
#
#
#
# 4it [00:12,  3.03s/it]
#
#
#
#
# 5it [00:15,  3.03s/it]
#
#
#
#  58%|█████▊    | 14/24 [03:25<02:27, 14.74s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.27s/it]
#
#
#
#
# 2it [00:06,  3.27s/it]
#
#
#
#
# 3it [00:09,  3.30s/it]
#
#
#
#
# 4it [00:13,  3.30s/it]
#
#
#
#
# 5it [00:16,  3.29s/it]
#
#
#
#  62%|██████▎   | 15/24 [03:41<02:17, 15.26s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.87s/it]
#
#
#
#
# 2it [00:05,  2.87s/it]
#
#
#
#
# 3it [00:08,  2.87s/it]
#
#
#
#
# 4it [00:11,  2.87s/it]
#
#
#
#
# 5it [00:14,  2.87s/it]
#
#
#
#  67%|██████▋   | 16/24 [03:55<01:59, 14.99s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.96s/it]
#
#
#
#
# 2it [00:05,  2.97s/it]
#
#
#
#
# 3it [00:08,  2.97s/it]
#
#
#
#
# 4it [00:11,  2.98s/it]
#
#
#
#
# 5it [00:14,  2.98s/it]
#
#
#
#  71%|███████   | 17/24 [04:10<01:44, 14.96s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.80s/it]
#
#
#
#
# 2it [00:05,  2.82s/it]
#
#
#
#
# 3it [00:08,  2.82s/it]
#
#
#
#
# 4it [00:11,  2.81s/it]
#
#
#
#
# 5it [00:14,  2.81s/it]
#
#
#
#  75%|███████▌  | 18/24 [04:24<01:28, 14.70s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.06s/it]
#
#
#
#
# 2it [00:06,  3.07s/it]
#
#
#
#
# 3it [00:09,  3.07s/it]
#
#
#
#
# 4it [00:12,  3.07s/it]
#
#
#
#
# 5it [00:15,  3.06s/it]
#
#
#
#  79%|███████▉  | 19/24 [04:40<01:14, 14.89s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.62s/it]
#
#
#
#
# 2it [00:05,  2.62s/it]
#
#
#
#
# 3it [00:07,  2.64s/it]
#
#
#
#
# 4it [00:10,  2.65s/it]
#
#
#
#
# 5it [00:13,  2.65s/it]
#
#
#
#  83%|████████▎ | 20/24 [04:53<00:57, 14.40s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.97s/it]
#
#
#
#
# 2it [00:05,  2.97s/it]
#
#
#
#
# 3it [00:08,  2.97s/it]
#
#
#
#
# 4it [00:11,  2.96s/it]
#
#
#
#
# 5it [00:14,  2.96s/it]
#
#
#
#  88%|████████▊ | 21/24 [05:08<00:43, 14.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.78s/it]
#
#
#
#
# 2it [00:05,  2.77s/it]
#
#
#
#
# 3it [00:08,  2.77s/it]
#
#
#
#
# 4it [00:11,  2.77s/it]
#
#
#
#
# 5it [00:13,  2.77s/it]
#
#
#
#  92%|█████████▏| 22/24 [05:22<00:28, 14.31s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:03,  3.01s/it]
#
#
#
#
# 2it [00:06,  3.01s/it]
#
#
#
#
# 3it [00:09,  3.01s/it]
#
#
#
#
# 4it [00:12,  3.01s/it]
#
#
#
#
# 5it [00:15,  3.01s/it]
#
#
#
#  96%|█████████▌| 23/24 [05:37<00:14, 14.53s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:02,  2.60s/it]
#
#
#
#
# 2it [00:05,  2.59s/it]
#
#
#
#
# 3it [00:07,  2.59s/it]
#
#
#
#
# 4it [00:10,  2.59s/it]
#
#
#
#
# 5it [00:12,  2.59s/it]
#
#
#
# 100%|██████████| 24/24 [05:50<00:00, 14.05s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.88s/it]
#
#
#
#
# 2it [00:31, 15.84s/it]
#
#
#
#
# 3it [00:47, 15.82s/it]
#
#
#
#
# 4it [01:03, 15.77s/it]
#
#
#
#
# 5it [01:18, 15.76s/it]
#
#
#
#   4%|▍         | 1/24 [01:18<30:12, 78.79s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.60s/it]
#
#
#
#
# 2it [00:29, 14.62s/it]
#
#
#
#
# 3it [00:43, 14.62s/it]
#
#
#
#
# 4it [00:58, 14.60s/it]
#
#
#
#
# 5it [01:13, 14.61s/it]
#
#
#
#   8%|▊         | 2/24 [02:31<28:15, 77.08s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.88s/it]
#
#
#
#
# 2it [00:31, 15.90s/it]
#
#
#
#
# 3it [00:47, 15.88s/it]
#
#
#
#
# 4it [01:03, 15.85s/it]
#
#
#
#
# 5it [01:19, 15.86s/it]
#
#
#
#  12%|█▎        | 3/24 [03:51<27:12, 77.75s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:13, 13.83s/it]
#
#
#
#
# 2it [00:27, 13.81s/it]
#
#
#
#
# 3it [00:41, 13.78s/it]
#
#
#
#
# 4it [00:54, 13.74s/it]
#
#
#
#
# 5it [01:08, 13.79s/it]
#
#
#
#  17%|█▋        | 4/24 [05:00<25:01, 75.09s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.48s/it]
#
#
#
#
# 2it [00:30, 15.48s/it]
#
#
#
#
# 3it [00:46, 15.49s/it]
#
#
#
#
# 4it [01:01, 15.49s/it]
#
#
#
#
# 5it [01:17, 15.59s/it]
#
#
#
#  21%|██        | 5/24 [06:17<24:02, 75.90s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.64s/it]
#
#
#
#
# 2it [00:29, 14.61s/it]
#
#
#
#
# 3it [00:43, 14.62s/it]
#
#
#
#
# 4it [00:58, 14.60s/it]
#
#
#
#
# 5it [01:12, 14.58s/it]
#
#
#
#  25%|██▌       | 6/24 [07:30<22:30, 75.01s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.89s/it]
#
#
#
#
# 2it [00:32, 15.99s/it]
#
#
#
#
# 3it [00:47, 15.93s/it]
#
#
#
#
# 4it [01:03, 15.88s/it]
#
#
#
#
# 5it [01:19, 15.90s/it]
#
#
#
#  29%|██▉       | 7/24 [08:50<21:38, 76.39s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:13, 13.94s/it]
#
#
#
#
# 2it [00:27, 13.89s/it]
#
#
#
#
# 3it [00:41, 13.84s/it]
#
#
#
#
# 4it [00:55, 13.86s/it]
#
#
#
#
# 5it [01:08, 13.80s/it]
#
#
#
#  33%|███▎      | 8/24 [09:59<19:46, 74.17s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.48s/it]
# 2it [00:30, 15.48s/it]
#
#
#
#
# 3it [00:46, 15.47s/it]
#
#
#
#
# 4it [01:02, 15.52s/it]
#
#
#
#
# 5it [01:17, 15.52s/it]
#
#
#
#  38%|███▊      | 9/24 [11:16<18:47, 75.19s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.97s/it]
#
#
#
#
# 2it [00:29, 14.85s/it]
#
#
#
#
# 3it [00:44, 14.76s/it]
#
#
#
#
# 4it [00:58, 14.78s/it]
#
#
#
#
# 5it [01:13, 14.71s/it]
#
#
#
#  42%|████▏     | 10/24 [12:30<17:25, 74.67s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.77s/it]
#
#
#
#
# 2it [00:31, 15.82s/it]
#
#
#
#
# 3it [00:47, 15.83s/it]
#
#
#
#
# 4it [01:03, 15.81s/it]
#
#
#
#
# 5it [01:19, 15.87s/it]
#
#
#
#  46%|████▌     | 11/24 [13:49<16:28, 76.07s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.02s/it]
#
#
#
#
# 2it [00:28, 14.02s/it]
#
#
#
#
# 3it [00:41, 13.89s/it]
#
#
#
#
# 4it [00:57, 14.54s/it]
#
#
#
#
# 5it [01:12, 14.54s/it]
#
#
#
#  50%|█████     | 12/24 [15:01<14:58, 74.91s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:17, 17.38s/it]
#
#
#
#
# 2it [00:34, 17.33s/it]
#
#
#
#
# 3it [00:52, 17.49s/it]
#
#
#
#
# 4it [01:09, 17.38s/it]
#
#
#
#
# 5it [01:27, 17.39s/it]
#
#
#
#  54%|█████▍    | 13/24 [16:28<14:23, 78.54s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:17, 17.00s/it]
#
#
#
#
# 2it [00:33, 16.87s/it]
#
#
#
#
# 3it [00:50, 16.83s/it]
#
#
#
#
# 4it [01:07, 16.85s/it]
#
#
#
#
# 5it [01:24, 16.96s/it]
#
#
#
#  58%|█████▊    | 14/24 [17:53<13:23, 80.30s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:18, 18.53s/it]
#
#
#
#
# 2it [00:36, 18.24s/it]
#
#
#
#
# 3it [00:53, 18.05s/it]
#
#
#
#
# 4it [01:12, 18.14s/it]
#
#
#
#
# 5it [01:30, 18.18s/it]
#
#
#
#  62%|██████▎   | 15/24 [19:23<12:29, 83.31s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.92s/it]
#
#
#
#
# 2it [00:31, 15.88s/it]
#
#
#
#
# 3it [00:47, 15.74s/it]
#
#
#
#
# 4it [01:02, 15.71s/it]
#
#
#
#
# 5it [01:18, 15.77s/it]
#
#
#
#  67%|██████▋   | 16/24 [20:42<10:55, 81.92s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.84s/it]
#
#
#
#
# 2it [00:31, 15.87s/it]
#
#
#
#
# 3it [00:47, 15.88s/it]
#
#
#
#
# 4it [01:03, 15.91s/it]
#
#
#
#
# 5it [01:19, 15.90s/it]
#
#
#
#  71%|███████   | 17/24 [22:01<09:28, 81.21s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.94s/it]
#
#
#
#
# 2it [00:29, 14.94s/it]
#
#
#
#
# 3it [00:44, 14.97s/it]
#
#
#
#
# 4it [00:59, 14.96s/it]
#
#
#
#
# 5it [01:14, 14.95s/it]
#
#
#
#  75%|███████▌  | 18/24 [23:16<07:55, 79.28s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.35s/it]
#
#
#
#
# 2it [00:32, 16.34s/it]
#
#
#
#
# 3it [00:49, 16.34s/it]
#
#
#
#
# 4it [01:05, 16.38s/it]
#
#
#
#
# 5it [01:21, 16.36s/it]
#
#
#
#  79%|███████▉  | 19/24 [24:38<06:40, 80.04s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:16, 16.54s/it]
#
#
#
#
# 2it [00:30, 15.85s/it]
#
#
#
#
# 3it [00:44, 15.27s/it]
#
#
#
#
# 4it [00:58, 14.87s/it]
#
#
#
#
# 5it [01:12, 14.61s/it]
#
#
#
#  83%|████████▎ | 20/24 [25:51<05:11, 77.83s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.72s/it]
#
#
#
#
# 2it [00:31, 15.72s/it]
#
#
#
#
# 3it [00:47, 15.72s/it]
#
#
#
#
# 4it [01:02, 15.73s/it]
#
#
#
#
# 5it [01:18, 15.76s/it]
#
#
#
#  88%|████████▊ | 21/24 [27:09<03:54, 78.10s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:14, 14.75s/it]
#
#
#
#
# 2it [00:29, 14.74s/it]
#
#
#
#
# 3it [00:44, 14.76s/it]
#
#
#
#
# 4it [00:58, 14.75s/it]
#
#
#
#
# 5it [01:13, 14.81s/it]
#
#
#
#  92%|█████████▏| 22/24 [28:23<02:33, 76.86s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:15, 15.99s/it]
#
#
#
#
# 2it [00:32, 16.01s/it]
#
#
#
#
# 3it [00:48, 16.04s/it]
#
#
#
#
# 4it [01:04, 16.02s/it]
#
#
#
#
# 5it [01:20, 16.01s/it]
#
#
#
#  96%|█████████▌| 23/24 [29:44<01:17, 77.84s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:13, 13.73s/it]
#
#
#
#
# 2it [00:27, 13.73s/it]
#
#
#
#
# 3it [00:41, 13.75s/it]
#
#
#
#
# 4it [00:55, 13.82s/it]
#
#
#
#
# 5it [01:09, 13.93s/it]
#
#
#
# 100%|██████████| 24/24 [30:53<00:00, 75.32s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.19s/it]
#
#
#
#
# 2it [00:16,  8.18s/it]
#
#
#
#
# 3it [00:24,  8.19s/it]
#
#
#
#
# 4it [00:32,  8.19s/it]
#
#
#
#
# 5it [00:40,  8.18s/it]
#
#
#
#   4%|▍         | 1/24 [00:40<15:41, 40.91s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.66s/it]
#
#
#
#
# 2it [00:15,  7.66s/it]
#
#
#
#
# 3it [00:23,  7.67s/it]
#
#
#
#
# 4it [00:30,  7.67s/it]
#
#
#
#
# 5it [00:38,  7.68s/it]
#
#
#
#   8%|▊         | 2/24 [01:19<14:43, 40.16s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.33s/it]
#
#
#
#
# 2it [00:16,  8.33s/it]
#
#
#
#
# 3it [00:24,  8.33s/it]
#
#
#
#
# 4it [00:33,  8.35s/it]
#
#
#
#
# 5it [00:41,  8.34s/it]
#
#
#
#  12%|█▎        | 3/24 [02:01<14:13, 40.62s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.20s/it]
#
#
#
#
# 2it [00:14,  7.19s/it]
#
#
#
#
# 3it [00:21,  7.18s/it]
#
#
#
#
# 4it [00:28,  7.19s/it]
#
#
#
#
# 5it [00:35,  7.20s/it]
#
#
#
#  17%|█▋        | 4/24 [02:36<13:04, 39.22s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.15s/it]
#
#
#
#
# 2it [00:16,  8.15s/it]
#
#
#
#
# 3it [00:24,  8.15s/it]
#
#
#
#
# 4it [00:32,  8.15s/it]
#
#
#
#
# 5it [00:40,  8.15s/it]
#
#
#
#  21%|██        | 5/24 [03:17<12:33, 39.68s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.66s/it]
#
#
#
#
# 2it [00:15,  7.66s/it]
#
#
#
#
# 3it [00:22,  7.66s/it]
#
#
#
#
# 4it [00:30,  7.66s/it]
#
#
#
#
# 5it [00:38,  7.66s/it]
#
#
#
#  25%|██▌       | 6/24 [03:55<11:46, 39.26s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.32s/it]
#
#
#
#
# 2it [00:16,  8.32s/it]
#
#
#
#
# 3it [00:24,  8.32s/it]
#
#
#
#
# 4it [00:33,  8.31s/it]
#
#
#
#
# 5it [00:41,  8.31s/it]
#
#
#
#  29%|██▉       | 7/24 [04:37<11:19, 39.95s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.17s/it]
#
#
#
#
# 2it [00:14,  7.17s/it]
#
#
#
#
# 3it [00:21,  7.18s/it]
#
#
#
#
# 4it [00:28,  7.17s/it]
#
#
#
#
# 5it [00:35,  7.17s/it]
#
#
#
#  33%|███▎      | 8/24 [05:13<10:19, 38.73s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.15s/it]
#
#
#
#
# 2it [00:16,  8.15s/it]
#
#
#
#
# 3it [00:24,  8.14s/it]
#
#
#
#
# 4it [00:32,  8.14s/it]
#
#
#
#
# 5it [00:40,  8.14s/it]
#
#
#
#  38%|███▊      | 9/24 [05:54<09:49, 39.32s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.66s/it]
#
#
#
#
# 2it [00:15,  7.66s/it]
#
#
#
#
# 3it [00:22,  7.65s/it]
#
#
#
#
# 4it [00:30,  7.65s/it]
#
#
#
#
# 5it [00:38,  7.65s/it]
#
#
#
#  42%|████▏     | 10/24 [06:32<09:06, 39.00s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.30s/it]
#
#
#
#
# 2it [00:16,  8.32s/it]
#
#
#
#
# 3it [00:24,  8.31s/it]
#
#
#
#
# 4it [00:33,  8.34s/it]
#
#
#
#
# 5it [00:41,  8.32s/it]
#
#
#
#  46%|████▌     | 11/24 [07:14<08:37, 39.80s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.18s/it]
#
#
#
#
# 2it [00:14,  7.17s/it]
#
#
#
#
# 3it [00:21,  7.17s/it]
#
#
#
#
# 4it [00:28,  7.16s/it]
#
#
#
#
# 5it [00:35,  7.17s/it]
#
#
#
#  50%|█████     | 12/24 [07:49<07:43, 38.61s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.29s/it]
#
#
#
#
# 2it [00:18,  9.35s/it]
#
#
#
#
# 3it [00:28,  9.39s/it]
#
#
#
#
# 4it [00:37,  9.33s/it]
#
#
#
#
# 5it [00:46,  9.29s/it]
#
#
#
#  54%|█████▍    | 13/24 [08:36<07:31, 41.02s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.98s/it]
#
#
#
#
# 2it [00:17,  8.93s/it]
#
#
#
#
# 3it [00:26,  8.88s/it]
#
#
#
#
# 4it [00:35,  8.91s/it]
#
#
#
#
# 5it [00:44,  8.92s/it]
#
#
#
#  58%|█████▊    | 14/24 [09:21<07:00, 42.06s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.57s/it]
#
#
#
#
# 2it [00:19,  9.57s/it]
#
#
#
#
# 3it [00:28,  9.58s/it]
#
#
#
#
# 4it [00:37,  9.47s/it]
#
#
#
#
# 5it [00:47,  9.46s/it]
#
#
#
#  62%|██████▎   | 15/24 [10:08<06:32, 43.66s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.12s/it]
#
#
#
#
# 2it [00:16,  8.14s/it]
#
#
#
#
# 3it [00:24,  8.17s/it]
#
#
#
#
# 4it [00:32,  8.14s/it]
#
#
#
#
# 5it [00:41,  8.23s/it]
#
#
#
#  67%|██████▋   | 16/24 [10:49<05:43, 42.88s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.31s/it]
#
#
#
#
# 2it [00:16,  8.32s/it]
#
#
#
#
# 3it [00:24,  8.33s/it]
#
#
#
#
# 4it [00:33,  8.33s/it]
#
#
#
#
# 5it [00:41,  8.34s/it]
#
#
#
#  71%|███████   | 17/24 [11:31<04:57, 42.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.84s/it]
#
#
#
#
# 2it [00:15,  7.88s/it]
#
#
#
#
# 3it [00:23,  7.87s/it]
#
#
#
#
# 4it [00:31,  7.87s/it]
#
#
#
#
# 5it [00:39,  7.86s/it]
#
#
#
#  75%|███████▌  | 18/24 [12:10<04:09, 41.58s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.58s/it]
#
#
#
#
# 2it [00:17,  8.57s/it]
#
#
#
#
# 3it [00:25,  8.57s/it]
#
#
#
#
# 4it [00:34,  8.57s/it]
#
#
#
#
# 5it [00:42,  8.58s/it]
#
#
#
#  79%|███████▉  | 19/24 [12:53<03:29, 41.97s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.32s/it]
#
#
#
#
# 2it [00:14,  7.32s/it]
#
#
#
#
# 3it [00:21,  7.32s/it]
#
#
#
#
# 4it [00:29,  7.32s/it]
#
#
#
#
# 5it [00:36,  7.32s/it]
#
#
#
#  83%|████████▎ | 20/24 [13:30<02:41, 40.36s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.25s/it]
#
#
#
#
# 2it [00:16,  8.25s/it]
#
#
#
#
# 3it [00:24,  8.26s/it]
#
#
#
#
# 4it [00:33,  8.26s/it]
#
#
#
#
# 5it [00:41,  8.27s/it]
#
#
#
#  88%|████████▊ | 21/24 [14:11<02:01, 40.65s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.73s/it]
#
#
#
#
# 2it [00:15,  7.73s/it]
#
#
#
#
# 3it [00:23,  7.73s/it]
#
#
#
#
# 4it [00:30,  7.74s/it]
#
#
#
#
# 5it [00:38,  7.74s/it]
#
#
#
#  92%|█████████▏| 22/24 [14:50<01:20, 40.07s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.40s/it]
#
#
#
#
# 2it [00:16,  8.40s/it]
#
#
#
#
# 3it [00:25,  8.41s/it]
#
#
#
#
# 4it [00:33,  8.44s/it]
#
#
#
#
# 5it [00:42,  8.43s/it]
#
#
#
#  96%|█████████▌| 23/24 [15:32<00:40, 40.70s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.22s/it]
#
#
#
#
# 2it [00:14,  7.22s/it]
#
#
#
#
# 3it [00:21,  7.22s/it]
#
#
#
#
# 4it [00:28,  7.23s/it]
#
#
#
#
# 5it [00:36,  7.23s/it]
#
#
#
# 100%|██████████| 24/24 [16:08<00:00, 39.34s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.91s/it]
#
#
#
#
# 2it [00:09,  4.91s/it]
#
#
#
#
# 3it [00:14,  4.90s/it]
#
#
#
#
# 4it [00:19,  4.90s/it]
#
#
#
#
# 5it [00:24,  4.90s/it]
#
#
#
#   4%|▍         | 1/24 [00:24<09:23, 24.50s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.59s/it]
#
#
#
#
# 2it [00:09,  4.59s/it]
#
#
#
#
# 3it [00:13,  4.59s/it]
#
#
#
#
# 4it [00:18,  4.60s/it]
#
#
#
#
# 5it [00:22,  4.59s/it]
#
#
#
#   8%|▊         | 2/24 [00:47<08:48, 24.04s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.04s/it]
#
#
#
#
# 2it [00:10,  5.03s/it]
#
#
#
#
# 3it [00:15,  5.02s/it]
#
#
#
#
# 4it [00:20,  5.01s/it]
#
#
#
#
# 5it [00:25,  5.01s/it]
#
#
#
#  12%|█▎        | 3/24 [01:12<08:31, 24.34s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.28s/it]
#
#
#
#
# 2it [00:08,  4.29s/it]
#
#
#
#
# 3it [00:12,  4.29s/it]
#
#
#
#
# 4it [00:17,  4.29s/it]
#
#
#
#
# 5it [00:21,  4.29s/it]
#
#
#
#  17%|█▋        | 4/24 [01:33<07:49, 23.48s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.89s/it]
#
#
#
#
# 2it [00:09,  4.89s/it]
#
#
#
#
# 3it [00:14,  4.88s/it]
#
#
#
#
# 4it [00:19,  4.88s/it]
#
#
#
#
# 5it [00:24,  4.89s/it]
#
#
#
#  21%|██        | 5/24 [01:58<07:31, 23.76s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.61s/it]
#
#
#
#
# 2it [00:09,  4.60s/it]
#
#
#
#
# 3it [00:13,  4.60s/it]
#
#
#
#
# 4it [00:18,  4.59s/it]
#
#
#
#
# 5it [00:22,  4.59s/it]
#
#
#
#  25%|██▌       | 6/24 [02:21<07:03, 23.52s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.97s/it]
#
#
#
#
# 2it [00:09,  4.97s/it]
#
#
#
#
# 3it [00:14,  4.97s/it]
#
#
#
#
# 4it [00:19,  4.98s/it]
#
#
#
#
# 5it [00:24,  4.97s/it]
#
#
#
#  29%|██▉       | 7/24 [02:46<06:46, 23.92s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.30s/it]
#
#
#
#
# 2it [00:08,  4.30s/it]
#
#
#
#
# 3it [00:12,  4.32s/it]
#
#
#
#
# 4it [00:17,  4.33s/it]
#
#
#
#
# 5it [00:21,  4.33s/it]
#
#
#
#  33%|███▎      | 8/24 [03:07<06:11, 23.24s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.94s/it]
#
#
#
#
# 2it [00:09,  4.92s/it]
#
#
#
#
# 3it [00:14,  4.91s/it]
#
#
#
#
# 4it [00:19,  4.90s/it]
#
#
#
#
# 5it [00:24,  4.89s/it]
#
#
#
#  38%|███▊      | 9/24 [03:32<05:54, 23.60s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.58s/it]
#
#
#
#
# 2it [00:09,  4.58s/it]
#
#
#
#
# 3it [00:13,  4.58s/it]
#
#
#
#
# 4it [00:18,  4.58s/it]
#
#
#
#
# 5it [00:22,  4.58s/it]
#
#
#
#  42%|████▏     | 10/24 [03:55<05:27, 23.40s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.99s/it]
#
#
#
#
# 2it [00:09,  4.98s/it]
#
#
#
#
# 3it [00:14,  4.98s/it]
#
#
#
#
# 4it [00:19,  4.98s/it]
#
#
#
#
# 5it [00:24,  4.98s/it]
#
#
#
#  46%|████▌     | 11/24 [04:20<05:09, 23.84s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.28s/it]
#
#
#
#
# 2it [00:08,  4.28s/it]
#
#
#
#
# 3it [00:12,  4.29s/it]
#
#
#
#
# 4it [00:17,  4.29s/it]
#
#
#
#
# 5it [00:21,  4.29s/it]
#
#
#
#  50%|█████     | 12/24 [04:41<04:37, 23.13s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.37s/it]
#
#
#
#
# 2it [00:10,  5.38s/it]
#
#
#
#
# 3it [00:16,  5.38s/it]
# 4it [00:21,  5.38s/it]
#
#
#
#
# 5it [00:26,  5.37s/it]
#
#
#
#  54%|█████▍    | 13/24 [05:08<04:26, 24.25s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.12s/it]
#
#
#
#
# 2it [00:10,  5.11s/it]
#
#
#
#
# 3it [00:15,  5.11s/it]
#
#
#
#
# 4it [00:20,  5.11s/it]
#
#
#
#
# 5it [00:25,  5.11s/it]
#
#
#
#  58%|█████▊    | 14/24 [05:34<04:06, 24.64s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.55s/it]
#
#
#
#
# 2it [00:11,  5.54s/it]
#
#
#
#
# 3it [00:16,  5.56s/it]
#
#
#
#
# 4it [00:22,  5.54s/it]
#
#
#
#
# 5it [00:27,  5.53s/it]
#
#
#
#  62%|██████▎   | 15/24 [06:01<03:49, 25.56s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.81s/it]
#
#
#
#
# 2it [00:09,  4.81s/it]
#
#
#
#
# 3it [00:14,  4.82s/it]
#
#
#
#
# 4it [00:19,  4.82s/it]
#
#
#
#
# 5it [00:24,  4.82s/it]
#
#
#
#  67%|██████▋   | 16/24 [06:25<03:21, 25.13s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  5.00s/it]
#
#
#
#
# 2it [00:09,  5.00s/it]
#
#
#
#
# 3it [00:15,  5.00s/it]
#
#
#
#
# 4it [00:20,  5.00s/it]
#
#
#
#
# 5it [00:24,  5.00s/it]
#
#
#
#  71%|███████   | 17/24 [06:50<02:55, 25.09s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.67s/it]
#
#
#
#
# 2it [00:09,  4.68s/it]
#
#
#
#
# 3it [00:14,  4.68s/it]
#
#
#
#
# 4it [00:18,  4.68s/it]
#
#
#
#
# 5it [00:23,  4.69s/it]
#
#
#
#  75%|███████▌  | 18/24 [07:14<02:27, 24.60s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.12s/it]
#
#
#
#
# 2it [00:10,  5.12s/it]
#
#
#
#
# 3it [00:15,  5.12s/it]
#
#
#
#
# 4it [00:20,  5.13s/it]
#
#
#
#
# 5it [00:25,  5.13s/it]
#
#
#
#  79%|███████▉  | 19/24 [07:39<02:04, 24.91s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.40s/it]
#
#
#
#
# 2it [00:08,  4.41s/it]
#
#
#
#
# 3it [00:13,  4.40s/it]
#
#
#
#
# 4it [00:17,  4.39s/it]
#
#
#
#
# 5it [00:21,  4.39s/it]
#
#
#
#  83%|████████▎ | 20/24 [08:01<01:36, 24.03s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.96s/it]
#
#
#
#
# 2it [00:10,  4.99s/it]
#
#
#
#
# 3it [00:14,  4.97s/it]
#
#
#
#
# 4it [00:19,  4.96s/it]
#
#
#
#
# 5it [00:24,  4.96s/it]
#
#
#
#  88%|████████▊ | 21/24 [08:26<01:12, 24.27s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.65s/it]
#
#
#
#
# 2it [00:09,  4.65s/it]
#
#
#
#
# 3it [00:13,  4.64s/it]
#
#
#
#
# 4it [00:18,  4.64s/it]
#
#
#
#
# 5it [00:23,  4.63s/it]
#
#
#
#  92%|█████████▏| 22/24 [08:49<00:47, 23.94s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:05,  5.02s/it]
#
#
#
#
# 2it [00:10,  5.03s/it]
#
#
#
#
# 3it [00:15,  5.03s/it]
#
#
#
#
# 4it [00:20,  5.03s/it]
#
#
#
#
# 5it [00:25,  5.03s/it]
#
#
#
#  96%|█████████▌| 23/24 [09:15<00:24, 24.32s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:04,  4.33s/it]
#
#
#
#
# 2it [00:08,  4.33s/it]
#
#
#
#
# 3it [00:13,  4.33s/it]
#
#
#
#
# 4it [00:17,  4.33s/it]
#
#
#
#
# 5it [00:21,  4.34s/it]
#
#
#
# 100%|██████████| 24/24 [09:36<00:00, 23.53s/it]
#
#
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.49s/it]
#
#
#
#
# 2it [00:16,  8.49s/it]
#
#
#
#
# 3it [00:25,  8.50s/it]
#
#
#
#
# 4it [00:33,  8.49s/it]
#
#
#
#
# 5it [00:42,  8.48s/it]
#
#
#
#   4%|▍         | 1/24 [00:42<16:15, 42.43s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.95s/it]
#
#
#
#
# 2it [00:15,  7.95s/it]
#
#
#
#
# 3it [00:23,  7.97s/it]
#
#
#
#
# 4it [00:31,  7.97s/it]
#
#
#
#
# 5it [00:39,  7.96s/it]
#
#
#
#   8%|▊         | 2/24 [01:22<15:16, 41.65s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.61s/it]
#
#
#
#
# 2it [00:17,  8.61s/it]
#
#
#
#
# 3it [00:25,  8.62s/it]
#
#
#
#
# 4it [00:34,  8.62s/it]
#
#
#
#
# 5it [00:43,  8.63s/it]
#
#
#
#  12%|█▎        | 3/24 [02:05<14:43, 42.09s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.44s/it]
#
#
#
#
# 2it [00:14,  7.44s/it]
#
#
#
#
# 3it [00:22,  7.44s/it]
#
#
#
#
# 4it [00:29,  7.44s/it]
#
#
#
#
# 5it [00:37,  7.43s/it]
#
#
#
#  17%|█▋        | 4/24 [02:42<13:32, 40.61s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.44s/it]
#
#
#
#
# 2it [00:16,  8.44s/it]
#
#
#
#
# 3it [00:25,  8.45s/it]
#
#
#
#
# 4it [00:33,  8.45s/it]
#
#
#
#
# 5it [00:42,  8.45s/it]
#
#
#
#  21%|██        | 5/24 [03:24<13:00, 41.11s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.99s/it]
#
#
#
#
# 2it [00:15,  7.99s/it]
#
#
#
#
# 3it [00:23,  7.98s/it]
#
#
#
#
# 4it [00:31,  7.97s/it]
#
#
#
#
# 5it [00:39,  7.96s/it]
#
#
#
#  25%|██▌       | 6/24 [04:04<12:12, 40.72s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.59s/it]
#
#
#
#
# 2it [00:17,  8.59s/it]
#
#
#
#
# 3it [00:25,  8.62s/it]
#
#
#
#
# 4it [00:34,  8.61s/it]
#
#
#
#
# 5it [00:43,  8.61s/it]
#
#
#
#  29%|██▉       | 7/24 [04:47<11:44, 41.43s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.43s/it]
#
#
#
#
# 2it [00:14,  7.43s/it]
#
#
#
#
# 3it [00:22,  7.43s/it]
#
#
#
#
# 4it [00:29,  7.43s/it]
#
#
#
#
# 5it [00:37,  7.43s/it]
#
#
#
#  33%|███▎      | 8/24 [05:24<10:42, 40.14s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.43s/it]
#
#
#
#
# 2it [00:16,  8.43s/it]
#
#
#
#
# 3it [00:25,  8.44s/it]
#
#
#
#
# 4it [00:33,  8.44s/it]
#
#
#
#
# 5it [00:42,  8.47s/it]
#
#
#
#  38%|███▊      | 9/24 [06:07<10:11, 40.79s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.93s/it]
#
#
#
#
# 2it [00:15,  7.94s/it]
#
#
#
#
# 3it [00:23,  7.94s/it]
#
#
#
#
# 4it [00:31,  7.94s/it]
#
#
#
#
# 5it [00:39,  7.94s/it]
#
#
#
#  42%|████▏     | 10/24 [06:46<09:26, 40.47s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.62s/it]
#
#
#
#
# 2it [00:17,  8.62s/it]
#
#
#
#
# 3it [00:25,  8.62s/it]
#
#
#
#
# 4it [00:34,  8.62s/it]
#
#
#
#
# 5it [00:43,  8.62s/it]
#
#
#
#  46%|████▌     | 11/24 [07:29<08:56, 41.26s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.43s/it]
#
#
#
#
# 2it [00:14,  7.43s/it]
#
#
#
#
# 3it [00:22,  7.42s/it]
#
#
#
#
# 4it [00:29,  7.42s/it]
#
#
#
#
# 5it [00:37,  7.43s/it]
#
#
#
#  50%|█████     | 12/24 [08:07<08:00, 40.02s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.33s/it]
#
#
#
#
# 2it [00:19,  9.44s/it]
#
#
#
#
# 3it [00:28,  9.46s/it]
#
#
#
#
# 4it [00:37,  9.43s/it]
#
#
#
#
# 5it [00:47,  9.41s/it]
#
#
#
#  54%|█████▍    | 13/24 [08:54<07:44, 42.19s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.88s/it]
#
#
#
#
# 2it [00:17,  8.88s/it]
#
#
#
#
# 3it [00:26,  8.93s/it]
#
#
#
#
# 4it [00:35,  8.96s/it]
#
#
#
#
# 5it [00:45,  9.07s/it]
#
#
#
#  58%|█████▊    | 14/24 [09:39<07:10, 43.08s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:09,  9.76s/it]
#
#
#
#
# 2it [00:19,  9.70s/it]
#
#
#
#
# 3it [00:28,  9.66s/it]
#
#
#
#
# 4it [00:38,  9.63s/it]
#
#
#
#
# 5it [00:48,  9.62s/it]
#
#
#
#  62%|██████▎   | 15/24 [10:27<06:41, 44.57s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.50s/it]
#
#
#
#
# 2it [00:16,  8.46s/it]
#
#
#
#
# 3it [00:25,  8.42s/it]
#
#
#
#
# 4it [00:33,  8.43s/it]
#
#
#
#
# 5it [00:42,  8.44s/it]
#
#
#
#  67%|██████▋   | 16/24 [11:09<05:50, 43.83s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.79s/it]
#
#
#
#
# 2it [00:17,  8.75s/it]
#
#
#
#
# 3it [00:26,  8.72s/it]
#
#
#
#
# 4it [00:34,  8.70s/it]
#
#
#
#
# 5it [00:43,  8.69s/it]
#
#
#
#  71%|███████   | 17/24 [11:53<05:05, 43.71s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.12s/it]
#
#
#
#
# 2it [00:16,  8.16s/it]
#
#
#
#
# 3it [00:24,  8.15s/it]
#
#
#
#
# 4it [00:32,  8.15s/it]
#
#
#
#
# 5it [00:40,  8.15s/it]
#
#
#
#  75%|███████▌  | 18/24 [12:33<04:16, 42.83s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.90s/it]
#
#
#
#
# 2it [00:17,  8.90s/it]
#
#
#
#
# 3it [00:26,  8.90s/it]
#
#
#
#
# 4it [00:35,  8.90s/it]
#
#
#
#
# 5it [00:44,  8.90s/it]
#
#
#
#  79%|███████▉  | 19/24 [13:18<03:36, 43.34s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.59s/it]
#
#
#
#
# 2it [00:15,  7.59s/it]
#
#
#
#
# 3it [00:22,  7.60s/it]
#
#
#
#
# 4it [00:30,  7.59s/it]
#
#
#
#
# 5it [00:37,  7.60s/it]
#
#
#
#  83%|████████▎ | 20/24 [13:56<02:46, 41.73s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.58s/it]
#
#
#
#
# 2it [00:17,  8.61s/it]
#
#
#
#
# 3it [00:25,  8.60s/it]
#
#
#
#
# 4it [00:34,  8.59s/it]
#
#
#
#
# 5it [00:42,  8.58s/it]
#
#
#
#  88%|████████▊ | 21/24 [14:39<02:06, 42.10s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.02s/it]
#
#
#
#
# 2it [00:16,  8.02s/it]
#
#
#
#
# 3it [00:24,  8.02s/it]
#
#
#
#
# 4it [00:32,  8.03s/it]
#
#
#
#
# 5it [00:40,  8.02s/it]
#
#
#
#  92%|█████████▏| 22/24 [15:19<01:23, 41.51s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:08,  8.72s/it]
#
#
#
#
# 2it [00:17,  8.72s/it]
#
#
#
#
# 3it [00:26,  8.72s/it]
#
#
#
#
# 4it [00:34,  8.74s/it]
#
#
#
#
# 5it [00:43,  8.74s/it]
#
#
#
#  96%|█████████▌| 23/24 [16:03<00:42, 42.16s/it]
#
#
#
#
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:07,  7.51s/it]
#
#
#
#
# 2it [00:14,  7.50s/it]
#
#
#
#
# 3it [00:22,  7.50s/it]
#
#
#
#
# 4it [00:29,  7.49s/it]
#
#
#
#
# 5it [00:37,  7.51s/it]
#
#
#
# 100%|██████████| 24/24 [16:40<00:00, 40.76s/it]

# %%
def get_result(data):
    R_list = []
    RMSE_list = []
    for model_index in range(len(data)):
        rmse_list = []
        r_list = []
        for k in range(5):
            pre = data[model_index][k]['prediction']
            truth = data[model_index][k]['truth']
            rmse = np.sqrt(sum((pre - truth)**2)/len(pre))
            r = pearsonr(pre,truth)[0]
            rmse_list.append(rmse)
            r_list.append(r)
        R_list.append(np.mean(r_list))
        RMSE_list.append(np.mean(rmse_list))
    return R_list, RMSE_list

# %%
def get_namelist():
    namelist = []
    for act in act_list:
        for opt in opt_list:
            namelist.append(act +'-'+ opt)
    return namelist

# %%
namelist = get_namelist()
namelist[:5]
# Out:
# ['sigmoid-adam',
#  'sigmoid-RMSprop',
#  'sigmoid-Adadelta',
#  'sigmoid-SGD',
#  'tanh-adam']

# %%
M1_final = get_result(M1_result)
M2_final = get_result(M2_result)
M3_final = get_result(M3_result)
M4_final = get_result(M4_result)
M5_final = get_result(M5_result)
M6_final = get_result(M6_result)
M7_final = get_result(M7_result)
M8_final = get_result(M8_result)

# %%
def plot_result(data):
    plt.figure(figsize = (9,9))
    p1 = plt.barh(y = range(24), width = data[0], height = 0.35, label = 'R')
    p2 = plt.barh(y = range(24), width = [0.3/i for i in data[1]], height = 0.35, label = '0.3/RMSE',left = data[0])
    plt.xlim(0,0.95,0.1)
    plt.yticks(range(24),(namelist))
    plt.ylabel('model_name',fontsize = 14)
    plt.legend()
    plt.show()

# %%
plot_result(M1_final)

# %%
plot_result(M2_final)

# %%
plot_result(M3_final)

# %%
plot_result(M4_final)

# %%
plot_result(M5_final)

# %%
plot_result(M6_final)

# %%
plot_result(M7_final)

# %%
plot_result(M8_final)

# %%
def cv_result(data):
    rmse_list = []
    r_list = []
    for k in range(5):
        pre = data[k]['prediction']
        truth = data[k]['truth']
        rmse = np.sqrt(sum((pre - truth)**2)/len(pre))
        r = pearsonr(pre,truth)[0]
        rmse_list.append(rmse)
        r_list.append(r)
    return np.mean(rmse_list), np.mean(r_list)

# %%
cv_result(benchmark)
# Out:
# (0.8443735002957752, 0.5408520997419529)

# %%
cv_result(orginal)
# Out:
# (1.71648575090252, 0.23005407621299012)

# %%
model.fit(X_train,y_train, epochs = 150, batch_size = 20, verbose = 0, validation_data = (X_test,y_test))
pre2 = model.predict(X_test)

# %%
plt.scatter(x = y2, y = pre22)
#plt.ylim(3,5.5)
plt.ylim(-4,3)
#plt.xlim(3,5.5)
plt.xlim(-4,3)
#plt.plot([3,5.5],[3,5.5],color = 'red')
plt.plot([-4,3],[-4,3], color = 'red')

# %%
plt.scatter(x = y_test, y = pre2)
plt.ylim(-4,3)
plt.xlim(-4,3)
plt.plot([-4,3],[-4,3],color = 'red')

# %%
# Out:
# 0.20653823

# %%
pre22 =( pre2 - pre2.mean())/pre2.std()
y2 = (y_test - y_test.mean())/y_test.std()
np.sqrt((sum((pre22.reshape(len(y_test),) - y2)**2))/len(y_test))
# Out:
# 1.023762501261837

# %%
pearsonr(pre22,y2.values.reshape(-1,1))
# Out:
# (array([0.47529801]), array([7.03002117e-24]))

# %%
np.sqrt((sum((pre.reshape(len(y_test),) - y_test)**2))/len(y_test))
# Out:
# 0.9078047181806805

# %%
pearsonr(pre,y_test.values.reshape(-1,1))
# Out:
# (array([0.49570273]), array([3.92512682e-26]))

# %%
plt.hist(stddata.loc[''])

# %%
error = M1_result[0][0]['prediction'] - M1_result[0][0]['truth']

# %%
[1,2,3] + []
# Out:
# [1, 2, 3]

# %% [markdown]
# ### error histgram

# %%
def get_error(data):
    error = []
    for k in range(5):
        temp = []
        temp = data[k]['prediction'] - data[k]['truth']
        temp = temp.tolist()
        error += temp
    return error

# %%
error = (get_error(M1_result[6])+get_error(M2_result[-11])+get_error(M3_result[12])+get_error(M4_result[-10])
        +get_error(M5_result[7])+get_error(M6_result[-2])+get_error(M7_result[-7])+get_error(M8_result[9]))

# %%
plt.hist(error,bins = 30 , range = (-4,4))
# Out:
# (array([2.000e+00, 0.000e+00, 4.000e+00, 6.000e+00, 1.400e+01, 2.200e+01,
#         4.600e+01, 1.040e+02, 1.420e+02, 2.460e+02, 4.720e+02, 9.060e+02,
#         1.476e+03, 1.921e+03, 2.080e+03, 1.856e+03, 1.496e+03, 1.040e+03,
#         6.960e+02, 4.450e+02, 2.970e+02, 1.950e+02, 1.480e+02, 9.400e+01,
#         5.500e+01, 4.100e+01, 2.700e+01, 8.000e+00, 3.000e+00, 4.000e+00]),
#  array([-4.        , -3.73333333, -3.46666667, -3.2       , -2.93333333,
#         -2.66666667, -2.4       , -2.13333333, -1.86666667, -1.6       ,
#         -1.33333333, -1.06666667, -0.8       , -0.53333333, -0.26666667,
#          0.        ,  0.26666667,  0.53333333,  0.8       ,  1.06666667,
#          1.33333333,  1.6       ,  1.86666667,  2.13333333,  2.4       ,
#          2.66666667,  2.93333333,  3.2       ,  3.46666667,  3.73333333,
#          4.        ]),
#  <a list of 30 Patch objects>)
